# %%
# Four‑layer ConvNet to facial emotion recognition with minimal epochs and the signifcance of data diversity
# data_dir = "C:/Users/Administrator/Desktop/data/jaffedbase/Jaffe"
import os
import cv2
import numpy as np
import tensorflow as tf
from skimage import feature
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from tensorflow.keras.layers import Input, Flatten, Dense, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Flatten, Dense, concatenate, Dropout  # Add Dropout here
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
# Set the path to your dataset folder.
data_dir = "C:/Users/Administrator/Desktop/data/Cancer_Inbreast/InBreast"

# Define a function to load and preprocess the images from the dataset folder.
def load_and_preprocess_images(data_dir):
    X_images = []
    y_labels = []
    
    for emotion_folder in os.listdir(data_dir):
        emotion_label = emotion_folder  # Assuming folder names are the labels.
        emotion_folder_path = os.path.join(data_dir, emotion_folder)
        
        for image_file in os.listdir(emotion_folder_path):
            image_path = os.path.join(emotion_folder_path, image_file)
            image = cv2.imread(image_path)
            # Resize the image to your desired dimensions (e.g., 128x128).
            image = cv2.resize(image, (128, 128))
            # Convert the image to grayscale.
            gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            X_images.append(gray_image)
            y_labels.append(emotion_label)
    
    return np.array(X_images), np.array(y_labels)

# Load and preprocess your facial images dataset.
X_images, y_labels = load_and_preprocess_images(data_dir)

# Define a function to extract LBP features from an image.
def extract_lbp_features(image):
    radius = 3
    n_points = 24
    lbp_image = feature.local_binary_pattern(image, n_points, radius, method="uniform")
    hist, _ = np.histogram(lbp_image.ravel(), bins=np.arange(0, n_points + 3), range=(0, n_points + 2))
    hist = hist.astype("float")
    hist /= (hist.sum() + 1e-6)
    return hist

# Extract LBP features from all images in your dataset.
X_lbp_features = [extract_lbp_features(image) for image in X_images]

# Convert the extracted LBP features to a NumPy array.
X_lbp_features = np.array(X_lbp_features)

# Define a function to create a CNN model for feature extraction from facial images.
def create_cnn_model(input_shape):
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((2, 2)))
    model.add(Dropout(0.25))
    
    model.add(tf.keras.layers.Conv2D(64, (3, 3),  activation='relu'))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((2, 2)))   
    model.add(Dropout(0.25))
    
    model.add(tf.keras.layers.Conv2D(128, (3, 3),  activation='relu'))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((2, 2))) 
    model.add(Dropout(0.25))
    
    model.add(tf.keras.layers.Conv2D(256, (3, 3),  activation='relu'))
    model.add(tf.keras.layers.MaxPooling2D((2, 2))) 
    model.add(Dropout(0.25))
    
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    return model
#model.summary()
# Define the input shape for your CNN model based on your image dimensions.
cnn_input_shape = (128, 128, 1)  # Assuming grayscale images with one channel.

# Create the CNN model.
cnn_model = create_cnn_model(cnn_input_shape)

# Define the combined model to concatenate CNN and LBP features.
cnn_output = cnn_model.output
lbp_input = Input(shape=(X_lbp_features.shape[1],))
concatenated = concatenate([cnn_output, lbp_input])
output = Dense(len(np.unique(y_labels)), activation='sigmoid')(concatenated)

model = Model(inputs=[cnn_model.input, lbp_input], outputs=output)

# Compile the combined model.
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Split your dataset into training and testing sets.
X_cnn_train, X_cnn_test, X_lbp_train, X_lbp_test, y_train, y_test = train_test_split(
    X_images, X_lbp_features, y_labels, test_size=0.2, random_state=42)

# Encode the labels using LabelEncoder and one-hot encoding.
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)
y_train_onehot = to_categorical(y_train_encoded)
y_test_onehot = to_categorical(y_test_encoded)

# Standardize the LBP features.
scaler = StandardScaler()
X_lbp_train = scaler.fit_transform(X_lbp_train)
X_lbp_test = scaler.transform(X_lbp_test)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Train the model.
history = model.fit([X_cnn_train, X_lbp_train], y_train_onehot, epochs=100, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set.
loss, accuracy = model.evaluate([X_cnn_test, X_lbp_test], y_test_onehot)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")

# Generate a classification report.
y_pred = model.predict([X_cnn_test, X_lbp_test])
y_pred_labels = label_encoder.inverse_transform(np.argmax(y_pred, axis=1))
print(classification_report(y_test, y_pred_labels))

# Generate a confusion matrix.
cm = confusion_matrix(y_test, y_pred_labels)

# Plot the confusion matrix as a heatmap.
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Epoch 1/100
# 153/153 [==============================] - 182s 1s/step - loss: 0.7742 - accuracy: 0.5832 - val_loss: 0.6162 - val_accuracy: 0.6945
# Epoch 2/100
# 153/153 [==============================] - 174s 1s/step - loss: 0.6532 - accuracy: 0.6734 - val_loss: 0.5955 - val_accuracy: 0.7117
# Epoch 3/100
# 153/153 [==============================] - 182s 1s/step - loss: 0.6211 - accuracy: 0.6801 - val_loss: 0.5981 - val_accuracy: 0.6953
# Epoch 4/100
# 153/153 [==============================] - 174s 1s/step - loss: 0.5955 - accuracy: 0.7028 - val_loss: 0.5759 - val_accuracy: 0.7305
# Epoch 5/100
# 153/153 [==============================] - 179s 1s/step - loss: 0.5838 - accuracy: 0.7059 - val_loss: 0.5716 - val_accuracy: 0.7453
# Epoch 6/100
# 153/153 [==============================] - 186s 1s/step - loss: 0.5687 - accuracy: 0.7209 - val_loss: 0.5505 - val_accuracy: 0.7559
# Epoch 7/100
# 153/153 [==============================] - 178s 1s/step - loss: 0.5593 - accuracy: 0.7213 - val_loss: 0.5719 - val_accuracy: 0.7371
# Epoch 8/100
# 153/153 [==============================] - 183s 1s/step - loss: 0.5492 - accuracy: 0.7278 - val_loss: 0.5654 - val_accuracy: 0.7355
# Epoch 9/100
# 153/153 [==============================] - 170s 1s/step - loss: 0.5422 - accuracy: 0.7366 - val_loss: 0.5863 - val_accuracy: 0.6814
# Epoch 10/100
# 153/153 [==============================] - 169s 1s/step - loss: 0.5305 - accuracy: 0.7432 - val_loss: 0.5277 - val_accuracy: 0.7666
# Epoch 11/100
# 153/153 [==============================] - 169s 1s/step - loss: 0.5228 - accuracy: 0.7444 - val_loss: 0.5396 - val_accuracy: 0.7232
# Epoch 12/100
# 153/153 [==============================] - 169s 1s/step - loss: 0.5034 - accuracy: 0.7586 - val_loss: 0.5027 - val_accuracy: 0.7649
# Epoch 13/100
# 153/153 [==============================] - 169s 1s/step - loss: 0.4910 - accuracy: 0.7663 - val_loss: 0.6533 - val_accuracy: 0.6962
# Epoch 14/100
# 153/153 [==============================] - 168s 1s/step - loss: 0.4727 - accuracy: 0.7780 - val_loss: 0.6520 - val_accuracy: 0.6126
# Epoch 15/100
# 153/153 [==============================] - 168s 1s/step - loss: 0.4357 - accuracy: 0.7944 - val_loss: 0.6232 - val_accuracy: 0.7117
# Epoch 16/100
# 153/153 [==============================] - 166s 1s/step - loss: 0.4183 - accuracy: 0.8071 - val_loss: 0.5540 - val_accuracy: 0.7453
# Epoch 17/100
# 153/153 [==============================] - 165s 1s/step - loss: 0.3851 - accuracy: 0.8265 - val_loss: 0.5026 - val_accuracy: 0.7559
# Epoch 18/100
# 153/153 [==============================] - 167s 1s/step - loss: 0.3619 - accuracy: 0.8454 - val_loss: 0.4305 - val_accuracy: 0.8198
# Epoch 19/100
# 153/153 [==============================] - 164s 1s/step - loss: 0.3366 - accuracy: 0.8548 - val_loss: 0.4779 - val_accuracy: 0.7805
# Epoch 20/100
# 153/153 [==============================] - 166s 1s/step - loss: 0.2930 - accuracy: 0.8745 - val_loss: 0.4848 - val_accuracy: 0.8059
# Epoch 21/100
# 153/153 [==============================] - 163s 1s/step - loss: 0.2556 - accuracy: 0.8923 - val_loss: 0.3529 - val_accuracy: 0.8608
# Epoch 22/100
# 153/153 [==============================] - 163s 1s/step - loss: 0.2368 - accuracy: 0.9019 - val_loss: 0.4887 - val_accuracy: 0.8395
# Epoch 23/100
# 153/153 [==============================] - 163s 1s/step - loss: 0.2166 - accuracy: 0.9144 - val_loss: 0.5377 - val_accuracy: 0.8108
# Epoch 24/100
# 153/153 [==============================] - 163s 1s/step - loss: 0.1907 - accuracy: 0.9218 - val_loss: 0.4340 - val_accuracy: 0.8387
# Epoch 25/100
# 153/153 [==============================] - 163s 1s/step - loss: 0.1614 - accuracy: 0.9396 - val_loss: 0.4122 - val_accuracy: 0.8354
# Epoch 26/100
# 153/153 [==============================] - 164s 1s/step - loss: 0.1496 - accuracy: 0.9453 - val_loss: 0.2785 - val_accuracy: 0.8952
# Epoch 27/100
# 153/153 [==============================] - 163s 1s/step - loss: 0.1375 - accuracy: 0.9470 - val_loss: 0.9406 - val_accuracy: 0.7445
# Epoch 28/100
# 153/153 [==============================] - 163s 1s/step - loss: 0.1548 - accuracy: 0.9425 - val_loss: 0.2678 - val_accuracy: 0.9066
# Epoch 29/100
# 153/153 [==============================] - 163s 1s/step - loss: 0.1379 - accuracy: 0.9468 - val_loss: 0.2470 - val_accuracy: 0.9001
# Epoch 30/100
# 153/153 [==============================] - 163s 1s/step - loss: 0.1068 - accuracy: 0.9615 - val_loss: 0.1860 - val_accuracy: 0.9369
# Epoch 31/100
# 153/153 [==============================] - 163s 1s/step - loss: 0.0990 - accuracy: 0.9642 - val_loss: 0.2757 - val_accuracy: 0.9206
# Epoch 32/100
# 153/153 [==============================] - 163s 1s/step - loss: 0.1042 - accuracy: 0.9627 - val_loss: 0.1649 - val_accuracy: 0.9410
# Epoch 33/100
# 153/153 [==============================] - 163s 1s/step - loss: 0.0859 - accuracy: 0.9691 - val_loss: 0.2808 - val_accuracy: 0.8853
# Epoch 34/100
# 153/153 [==============================] - 163s 1s/step - loss: 0.0783 - accuracy: 0.9713 - val_loss: 0.1678 - val_accuracy: 0.9459
# Epoch 35/100
# 153/153 [==============================] - 168s 1s/step - loss: 0.0946 - accuracy: 0.9635 - val_loss: 0.1955 - val_accuracy: 0.9353
# Epoch 36/100
# 153/153 [==============================] - 179s 1s/step - loss: 0.0911 - accuracy: 0.9666 - val_loss: 0.4129 - val_accuracy: 0.8583
# Epoch 37/100
# 153/153 [==============================] - 181s 1s/step - loss: 0.0746 - accuracy: 0.9740 - val_loss: 0.3294 - val_accuracy: 0.8927
# Epoch 38/100
# 153/153 [==============================] - 170s 1s/step - loss: 0.0740 - accuracy: 0.9719 - val_loss: 0.1938 - val_accuracy: 0.9361
# Epoch 39/100
# 153/153 [==============================] - 178s 1s/step - loss: 0.0605 - accuracy: 0.9793 - val_loss: 0.1747 - val_accuracy: 0.9451
# Epoch 40/100
# 153/153 [==============================] - 189s 1s/step - loss: 0.0610 - accuracy: 0.9777 - val_loss: 0.1715 - val_accuracy: 0.9525
# Epoch 41/100
# 153/153 [==============================] - 185s 1s/step - loss: 0.0559 - accuracy: 0.9779 - val_loss: 0.2011 - val_accuracy: 0.9402
# Epoch 42/100
# 153/153 [==============================] - 179s 1s/step - loss: 0.0762 - accuracy: 0.9711 - val_loss: 0.2036 - val_accuracy: 0.9435
# Epoch 43/100
# 153/153 [==============================] - 169s 1s/step - loss: 0.0540 - accuracy: 0.9812 - val_loss: 0.2114 - val_accuracy: 0.9435
# Epoch 44/100
# 153/153 [==============================] - 171s 1s/step - loss: 0.0466 - accuracy: 0.9836 - val_loss: 0.6873 - val_accuracy: 0.8346
# Epoch 45/100
# 153/153 [==============================] - 170s 1s/step - loss: 0.0548 - accuracy: 0.9805 - val_loss: 0.1630 - val_accuracy: 0.9378
# Epoch 46/100
# 153/153 [==============================] - 170s 1s/step - loss: 0.0486 - accuracy: 0.9824 - val_loss: 0.5045 - val_accuracy: 0.8657
# Epoch 47/100
# 153/153 [==============================] - 170s 1s/step - loss: 0.0585 - accuracy: 0.9812 - val_loss: 0.2328 - val_accuracy: 0.9378
# Epoch 48/100
# 153/153 [==============================] - 170s 1s/step - loss: 0.0570 - accuracy: 0.9795 - val_loss: 0.1576 - val_accuracy: 0.9509
# Epoch 49/100
# 153/153 [==============================] - 170s 1s/step - loss: 0.0489 - accuracy: 0.9805 - val_loss: 0.5931 - val_accuracy: 0.8608
# Epoch 50/100
# 153/153 [==============================] - 170s 1s/step - loss: 0.0504 - accuracy: 0.9820 - val_loss: 0.1599 - val_accuracy: 0.9517
# Epoch 51/100
# 153/153 [==============================] - 170s 1s/step - loss: 0.0541 - accuracy: 0.9797 - val_loss: 0.2547 - val_accuracy: 0.9459
# Epoch 52/100
# 153/153 [==============================] - 170s 1s/step - loss: 0.0525 - accuracy: 0.9797 - val_loss: 0.1459 - val_accuracy: 0.9590
# Epoch 53/100
# 153/153 [==============================] - 170s 1s/step - loss: 0.0454 - accuracy: 0.9840 - val_loss: 0.9887 - val_accuracy: 0.8108
# Epoch 54/100
# 153/153 [==============================] - 170s 1s/step - loss: 0.0417 - accuracy: 0.9838 - val_loss: 0.2507 - val_accuracy: 0.9320
# Epoch 55/100
# 153/153 [==============================] - 170s 1s/step - loss: 0.0668 - accuracy: 0.9767 - val_loss: 0.3847 - val_accuracy: 0.9017
# Epoch 56/100
# 153/153 [==============================] - 170s 1s/step - loss: 0.0541 - accuracy: 0.9795 - val_loss: 0.2261 - val_accuracy: 0.9386
# Epoch 57/100
# 153/153 [==============================] - 168s 1s/step - loss: 0.0445 - accuracy: 0.9838 - val_loss: 0.2404 - val_accuracy: 0.9394
# Epoch 58/100
# 153/153 [==============================] - 168s 1s/step - loss: 0.0415 - accuracy: 0.9838 - val_loss: 0.1628 - val_accuracy: 0.9484
# Epoch 59/100
# 153/153 [==============================] - 168s 1s/step - loss: 0.0419 - accuracy: 0.9851 - val_loss: 0.1559 - val_accuracy: 0.9533
# Epoch 60/100
# 153/153 [==============================] - 168s 1s/step - loss: 0.0309 - accuracy: 0.9896 - val_loss: 0.1620 - val_accuracy: 0.9590
# Epoch 61/100
# 153/153 [==============================] - 168s 1s/step - loss: 0.0269 - accuracy: 0.9910 - val_loss: 0.3341 - val_accuracy: 0.9165
# Epoch 62/100
# 153/153 [==============================] - 168s 1s/step - loss: 0.0342 - accuracy: 0.9863 - val_loss: 0.2643 - val_accuracy: 0.9189
# Epoch 63/100
# 153/153 [==============================] - 168s 1s/step - loss: 0.0360 - accuracy: 0.9873 - val_loss: 0.2374 - val_accuracy: 0.9378
# Epoch 64/100
# 153/153 [==============================] - 168s 1s/step - loss: 0.0424 - accuracy: 0.9842 - val_loss: 0.1572 - val_accuracy: 0.9574
# Epoch 65/100
# 153/153 [==============================] - 168s 1s/step - loss: 0.0460 - accuracy: 0.9838 - val_loss: 0.1615 - val_accuracy: 0.9451
# Epoch 66/100
# 153/153 [==============================] - 168s 1s/step - loss: 0.0263 - accuracy: 0.9912 - val_loss: 0.3838 - val_accuracy: 0.9115
# Epoch 67/100
# 153/153 [==============================] - 168s 1s/step - loss: 0.0421 - accuracy: 0.9857 - val_loss: 0.2360 - val_accuracy: 0.9337
# Epoch 68/100
# 153/153 [==============================] - 168s 1s/step - loss: 0.0423 - accuracy: 0.9855 - val_loss: 0.1810 - val_accuracy: 0.9500
# Epoch 69/100
# 153/153 [==============================] - 168s 1s/step - loss: 0.0515 - accuracy: 0.9820 - val_loss: 0.2099 - val_accuracy: 0.9517
# Epoch 70/100
# 153/153 [==============================] - 168s 1s/step - loss: 0.0390 - accuracy: 0.9873 - val_loss: 0.1986 - val_accuracy: 0.9558
# Epoch 71/100
# 153/153 [==============================] - 168s 1s/step - loss: 0.0329 - accuracy: 0.9894 - val_loss: 0.3993 - val_accuracy: 0.9140
# Epoch 72/100
# 153/153 [==============================] - 168s 1s/step - loss: 0.0263 - accuracy: 0.9916 - val_loss: 0.2120 - val_accuracy: 0.9296
# Epoch 73/100
# 153/153 [==============================] - 168s 1s/step - loss: 0.0361 - accuracy: 0.9891 - val_loss: 0.2688 - val_accuracy: 0.9402
# Epoch 74/100
# 153/153 [==============================] - 169s 1s/step - loss: 0.0295 - accuracy: 0.9904 - val_loss: 0.1867 - val_accuracy: 0.9378
# Epoch 75/100
# 153/153 [==============================] - 169s 1s/step - loss: 0.0295 - accuracy: 0.9885 - val_loss: 0.1343 - val_accuracy: 0.9607
# Epoch 76/100
# 153/153 [==============================] - 169s 1s/step - loss: 0.0295 - accuracy: 0.9894 - val_loss: 0.1640 - val_accuracy: 0.9500
# Epoch 77/100
# 153/153 [==============================] - 169s 1s/step - loss: 0.0334 - accuracy: 0.9877 - val_loss: 0.1659 - val_accuracy: 0.9443
# Epoch 78/100
# 153/153 [==============================] - 169s 1s/step - loss: 0.0407 - accuracy: 0.9851 - val_loss: 0.1678 - val_accuracy: 0.9590
# Epoch 79/100
# 153/153 [==============================] - 170s 1s/step - loss: 0.0328 - accuracy: 0.9883 - val_loss: 0.1373 - val_accuracy: 0.9615
# Epoch 80/100
# 153/153 [==============================] - 170s 1s/step - loss: 0.0312 - accuracy: 0.9889 - val_loss: 0.1588 - val_accuracy: 0.9558
# Epoch 81/100
# 153/153 [==============================] - 170s 1s/step - loss: 0.0247 - accuracy: 0.9924 - val_loss: 0.4070 - val_accuracy: 0.9099
# Epoch 82/100
# 153/153 [==============================] - 170s 1s/step - loss: 0.0273 - accuracy: 0.9924 - val_loss: 0.2173 - val_accuracy: 0.9492
# Epoch 83/100
# 153/153 [==============================] - 170s 1s/step - loss: 0.0345 - accuracy: 0.9904 - val_loss: 0.2030 - val_accuracy: 0.9500
# Epoch 84/100
# 153/153 [==============================] - 171s 1s/step - loss: 0.0223 - accuracy: 0.9920 - val_loss: 0.1841 - val_accuracy: 0.9525
# Epoch 85/100
# 153/153 [==============================] - 171s 1s/step - loss: 0.0325 - accuracy: 0.9885 - val_loss: 0.1766 - val_accuracy: 0.9590
# Epoch 86/100
# 153/153 [==============================] - 171s 1s/step - loss: 0.0303 - accuracy: 0.9879 - val_loss: 0.2709 - val_accuracy: 0.9328
# Epoch 87/100
# 153/153 [==============================] - 171s 1s/step - loss: 0.0250 - accuracy: 0.9916 - val_loss: 0.1645 - val_accuracy: 0.9599
# Epoch 88/100
# 153/153 [==============================] - 172s 1s/step - loss: 0.0273 - accuracy: 0.9900 - val_loss: 0.6532 - val_accuracy: 0.8600
# Epoch 89/100
# 153/153 [==============================] - 172s 1s/step - loss: 0.0278 - accuracy: 0.9894 - val_loss: 1.1387 - val_accuracy: 0.8231
# Epoch 90/100
# 153/153 [==============================] - 173s 1s/step - loss: 0.0276 - accuracy: 0.9918 - val_loss: 0.1694 - val_accuracy: 0.9574
# Epoch 91/100
# 153/153 [==============================] - 172s 1s/step - loss: 0.0205 - accuracy: 0.9943 - val_loss: 0.4136 - val_accuracy: 0.8862
# Epoch 92/100
# 153/153 [==============================] - 173s 1s/step - loss: 0.0403 - accuracy: 0.9869 - val_loss: 0.2007 - val_accuracy: 0.9509
# Epoch 93/100
# 153/153 [==============================] - 173s 1s/step - loss: 0.0390 - accuracy: 0.9861 - val_loss: 0.1655 - val_accuracy: 0.9590
# Epoch 94/100
# 153/153 [==============================] - 174s 1s/step - loss: 0.0328 - accuracy: 0.9871 - val_loss: 1.5760 - val_accuracy: 0.7445
# Epoch 95/100
# 153/153 [==============================] - 174s 1s/step - loss: 0.0284 - accuracy: 0.9889 - val_loss: 0.2341 - val_accuracy: 0.9165
# Epoch 96/100
# 153/153 [==============================] - 174s 1s/step - loss: 0.0240 - accuracy: 0.9918 - val_loss: 0.3180 - val_accuracy: 0.9255
# Epoch 97/100
# 153/153 [==============================] - 174s 1s/step - loss: 0.0262 - accuracy: 0.9906 - val_loss: 0.1633 - val_accuracy: 0.9640
# Epoch 98/100
# 153/153 [==============================] - 175s 1s/step - loss: 0.0248 - accuracy: 0.9906 - val_loss: 0.2008 - val_accuracy: 0.9353
# Epoch 99/100
# 153/153 [==============================] - 176s 1s/step - loss: 0.0268 - accuracy: 0.9906 - val_loss: 0.1718 - val_accuracy: 0.9476
# Epoch 100/100
# 153/153 [==============================] - 175s 1s/step - loss: 0.0211 - accuracy: 0.9934 - val_loss: 0.1743 - val_accuracy: 0.9599
# 48/48 [==============================] - 12s 256ms/step - loss: 0.1318 - accuracy: 0.9581
# Test Loss: 0.1318, Test Accuracy: 0.9581
#               precision    recall  f1-score   support
#
#       benign       0.95      0.93      0.94       539
#    malignant       0.96      0.97      0.97       988
#
#     accuracy                           0.96      1527
#    macro avg       0.96      0.95      0.95      1527
# weighted avg       0.96      0.96      0.96      1527

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Compute ROC curve and ROC area for each class
fpr = {}
tpr = {}
roc_auc = {}
n_classes = len(np.unique(y_labels))
y_score = model.predict([X_cnn_test, X_lbp_test])
y_test_categorical = to_categorical(label_encoder.transform(y_test))
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_categorical[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Access the training history to plot the training and validation loss and accuracy.
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

# Plot training versus validation loss
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()

# Plot training versus validation accuracy
plt.subplot(1, 2, 2)
plt.plot(training_accuracy, label='Training Accuracy')
plt.plot(validation_accuracy, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report, cohen_kappa_score
# Calculate the kappa statistic.
kappa_statistic = cohen_kappa_score(y_test, y_pred_labels)
print(f"Kappa Statistic: {kappa_statistic:.4f}")

# Calculate the False Negative Rate.
TN, FP, FN, TP = cm.ravel()
FNR = FN / (FN + TP)
print(f"False Negative Rate: {FNR:.4f}")
# Out:
# Kappa Statistic: 0.9078
# False Negative Rate: 0.0263

# %%
from sklearn.metrics import recall_score


# Calculate the sensitivity (true positive rate).
sensitivity = recall_score(y_test, y_pred_labels, average='macro')
print(f"Sensitivity (True Positive Rate): {sensitivity:.4f}")
# Out:
# Sensitivity (True Positive Rate): 0.9516
