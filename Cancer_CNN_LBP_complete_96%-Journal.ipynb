# %%
# Four‑layer ConvNet to facial emotion recognition with minimal epochs and the signifcance of data diversity
# data_dir = "C:/Users/Administrator/Desktop/data/jaffedbase/Jaffe"
import os
import cv2
import numpy as np
import tensorflow as tf
from skimage import feature
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from tensorflow.keras.layers import Input, Flatten, Dense, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Flatten, Dense, concatenate, Dropout  # Add Dropout here
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
# Set the path to your dataset folder.
data_dir = "C:/Users/Administrator/Desktop/data/cancer"

# Define a function to load and preprocess the images from the dataset folder.
def load_and_preprocess_images(data_dir):
    X_images = []
    y_labels = []
    
    for emotion_folder in os.listdir(data_dir):
        emotion_label = emotion_folder  # Assuming folder names are the labels.
        emotion_folder_path = os.path.join(data_dir, emotion_folder)
        
        for image_file in os.listdir(emotion_folder_path):
            image_path = os.path.join(emotion_folder_path, image_file)
            image = cv2.imread(image_path)
            # Resize the image to your desired dimensions (e.g., 128x128).
            image = cv2.resize(image, (128, 128))
            # Convert the image to grayscale.
            gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            X_images.append(gray_image)
            y_labels.append(emotion_label)
    
    return np.array(X_images), np.array(y_labels)

# Load and preprocess your facial images dataset.
X_images, y_labels = load_and_preprocess_images(data_dir)

# Define a function to extract LBP features from an image.
def extract_lbp_features(image):
    radius = 3
    n_points = 24
    lbp_image = feature.local_binary_pattern(image, n_points, radius, method="uniform")
    hist, _ = np.histogram(lbp_image.ravel(), bins=np.arange(0, n_points + 3), range=(0, n_points + 2))
    hist = hist.astype("float")
    hist /= (hist.sum() + 1e-6)
    return hist

# Extract LBP features from all images in your dataset.
X_lbp_features = [extract_lbp_features(image) for image in X_images]

# Convert the extracted LBP features to a NumPy array.
X_lbp_features = np.array(X_lbp_features)

# Define a function to create a CNN model for feature extraction from facial images.
def create_cnn_model(input_shape):
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((2, 2)))
    model.add(Dropout(0.25))
    
    model.add(tf.keras.layers.Conv2D(64, (3, 3),  activation='relu'))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((2, 2)))   
    model.add(Dropout(0.25))
    
    model.add(tf.keras.layers.Conv2D(128, (3, 3),  activation='relu'))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((2, 2))) 
    model.add(Dropout(0.25))
    
    model.add(tf.keras.layers.Conv2D(256, (3, 3),  activation='relu'))
    model.add(tf.keras.layers.MaxPooling2D((2, 2))) 
    model.add(Dropout(0.25))
    
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    return model
#model.summary()
# Define the input shape for your CNN model based on your image dimensions.
cnn_input_shape = (128, 128, 1)  # Assuming grayscale images with one channel.

# Create the CNN model.
cnn_model = create_cnn_model(cnn_input_shape)

# Define the combined model to concatenate CNN and LBP features.
cnn_output = cnn_model.output
lbp_input = Input(shape=(X_lbp_features.shape[1],))
concatenated = concatenate([cnn_output, lbp_input])
output = Dense(len(np.unique(y_labels)), activation='sigmoid')(concatenated)

model = Model(inputs=[cnn_model.input, lbp_input], outputs=output)

# Compile the combined model.
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Split your dataset into training and testing sets.
X_cnn_train, X_cnn_test, X_lbp_train, X_lbp_test, y_train, y_test = train_test_split(
    X_images, X_lbp_features, y_labels, test_size=0.2, random_state=42)

# Encode the labels using LabelEncoder and one-hot encoding.
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)
y_train_onehot = to_categorical(y_train_encoded)
y_test_onehot = to_categorical(y_test_encoded)

# Standardize the LBP features.
scaler = StandardScaler()
X_lbp_train = scaler.fit_transform(X_lbp_train)
X_lbp_test = scaler.transform(X_lbp_test)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Train the model.
history = model.fit([X_cnn_train, X_lbp_train], y_train_onehot, epochs=100, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set.
loss, accuracy = model.evaluate([X_cnn_test, X_lbp_test], y_test_onehot)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")

# Generate a classification report.
y_pred = model.predict([X_cnn_test, X_lbp_test])
y_pred_labels = label_encoder.inverse_transform(np.argmax(y_pred, axis=1))
print(classification_report(y_test, y_pred_labels))

# Generate a confusion matrix.
cm = confusion_matrix(y_test, y_pred_labels)

# Plot the confusion matrix as a heatmap.
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Epoch 1/100
# 77/77 [==============================] - 85s 1s/step - loss: 0.8176 - accuracy: 0.6075 - val_loss: 0.7442 - val_accuracy: 0.5957
# Epoch 2/100
# 77/77 [==============================] - 84s 1s/step - loss: 0.7026 - accuracy: 0.6469 - val_loss: 0.6682 - val_accuracy: 0.5925
# Epoch 3/100
# 77/77 [==============================] - 84s 1s/step - loss: 0.6649 - accuracy: 0.6604 - val_loss: 0.7323 - val_accuracy: 0.5368
# Epoch 4/100
# 77/77 [==============================] - 84s 1s/step - loss: 0.6501 - accuracy: 0.6784 - val_loss: 0.6718 - val_accuracy: 0.6219
# Epoch 5/100
# 77/77 [==============================] - 91s 1s/step - loss: 0.6287 - accuracy: 0.6919 - val_loss: 0.6333 - val_accuracy: 0.6530
# Epoch 6/100
# 77/77 [==============================] - 88s 1s/step - loss: 0.6113 - accuracy: 0.6858 - val_loss: 0.6136 - val_accuracy: 0.6530
# Epoch 7/100
# 77/77 [==============================] - 90s 1s/step - loss: 0.5846 - accuracy: 0.7005 - val_loss: 0.6169 - val_accuracy: 0.6890
# Epoch 8/100
# 77/77 [==============================] - 86s 1s/step - loss: 0.5874 - accuracy: 0.7059 - val_loss: 0.5964 - val_accuracy: 0.6874
# Epoch 9/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.5688 - accuracy: 0.7079 - val_loss: 0.5707 - val_accuracy: 0.6907
# Epoch 10/100
# 77/77 [==============================] - 84s 1s/step - loss: 0.5378 - accuracy: 0.7300 - val_loss: 0.5644 - val_accuracy: 0.6972
# Epoch 11/100
# 77/77 [==============================] - 85s 1s/step - loss: 0.5004 - accuracy: 0.7476 - val_loss: 0.5834 - val_accuracy: 0.7021
# Epoch 12/100
# 77/77 [==============================] - 84s 1s/step - loss: 0.4843 - accuracy: 0.7661 - val_loss: 0.5448 - val_accuracy: 0.7152
# Epoch 13/100
# 77/77 [==============================] - 84s 1s/step - loss: 0.4717 - accuracy: 0.7816 - val_loss: 0.7228 - val_accuracy: 0.6088
# Epoch 14/100
# 77/77 [==============================] - 84s 1s/step - loss: 0.4250 - accuracy: 0.8103 - val_loss: 0.8341 - val_accuracy: 0.6121
# Epoch 15/100
# 77/77 [==============================] - 84s 1s/step - loss: 0.4035 - accuracy: 0.8177 - val_loss: 0.7970 - val_accuracy: 0.6301
# Epoch 16/100
# 77/77 [==============================] - 84s 1s/step - loss: 0.3644 - accuracy: 0.8464 - val_loss: 0.4574 - val_accuracy: 0.7872
# Epoch 17/100
# 77/77 [==============================] - 84s 1s/step - loss: 0.3440 - accuracy: 0.8464 - val_loss: 0.4200 - val_accuracy: 0.8036
# Epoch 18/100
# 77/77 [==============================] - 84s 1s/step - loss: 0.3139 - accuracy: 0.8669 - val_loss: 0.4561 - val_accuracy: 0.7758
# Epoch 19/100
# 77/77 [==============================] - 84s 1s/step - loss: 0.3154 - accuracy: 0.8611 - val_loss: 0.6415 - val_accuracy: 0.6907
# Epoch 20/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.2867 - accuracy: 0.8816 - val_loss: 0.4296 - val_accuracy: 0.8069
# Epoch 21/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.2505 - accuracy: 0.8902 - val_loss: 0.3641 - val_accuracy: 0.8429
# Epoch 22/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.2223 - accuracy: 0.9132 - val_loss: 0.4997 - val_accuracy: 0.7938
# Epoch 23/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.1918 - accuracy: 0.9304 - val_loss: 0.4137 - val_accuracy: 0.7872
# Epoch 24/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.1795 - accuracy: 0.9328 - val_loss: 0.3458 - val_accuracy: 0.8592
# Epoch 25/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.2143 - accuracy: 0.9230 - val_loss: 0.6354 - val_accuracy: 0.7512
# Epoch 26/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.1621 - accuracy: 0.9398 - val_loss: 0.3873 - val_accuracy: 0.8314
# Epoch 27/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.1484 - accuracy: 0.9455 - val_loss: 0.2628 - val_accuracy: 0.8756
# Epoch 28/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.1194 - accuracy: 0.9603 - val_loss: 0.4850 - val_accuracy: 0.8134
# Epoch 29/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.1094 - accuracy: 0.9570 - val_loss: 0.2640 - val_accuracy: 0.8920
# Epoch 30/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0907 - accuracy: 0.9619 - val_loss: 0.2959 - val_accuracy: 0.8789
# Epoch 31/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.1149 - accuracy: 0.9570 - val_loss: 0.2375 - val_accuracy: 0.9018
# Epoch 32/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.1929 - accuracy: 0.9271 - val_loss: 0.4150 - val_accuracy: 0.8429
# Epoch 33/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.1442 - accuracy: 0.9496 - val_loss: 0.3344 - val_accuracy: 0.8658
# Epoch 34/100
# 77/77 [==============================] - 85s 1s/step - loss: 0.1027 - accuracy: 0.9627 - val_loss: 0.4447 - val_accuracy: 0.8282
# Epoch 35/100
# 77/77 [==============================] - 97s 1s/step - loss: 0.1151 - accuracy: 0.9603 - val_loss: 0.2270 - val_accuracy: 0.9296
# Epoch 36/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0834 - accuracy: 0.9705 - val_loss: 0.4416 - val_accuracy: 0.8298
# Epoch 37/100
# 77/77 [==============================] - 96s 1s/step - loss: 0.0823 - accuracy: 0.9730 - val_loss: 0.2348 - val_accuracy: 0.9034
# Epoch 38/100
# 77/77 [==============================] - 95s 1s/step - loss: 0.0592 - accuracy: 0.9783 - val_loss: 0.2100 - val_accuracy: 0.9296
# Epoch 39/100
# 77/77 [==============================] - 94s 1s/step - loss: 0.0598 - accuracy: 0.9766 - val_loss: 0.1867 - val_accuracy: 0.9444
# Epoch 40/100
# 77/77 [==============================] - 94s 1s/step - loss: 0.0472 - accuracy: 0.9844 - val_loss: 0.2107 - val_accuracy: 0.9149
# Epoch 41/100
# 77/77 [==============================] - 98s 1s/step - loss: 0.0554 - accuracy: 0.9812 - val_loss: 0.2425 - val_accuracy: 0.9116
# Epoch 42/100
# 77/77 [==============================] - 91s 1s/step - loss: 0.0640 - accuracy: 0.9758 - val_loss: 0.2703 - val_accuracy: 0.9165
# Epoch 43/100
# 77/77 [==============================] - 94s 1s/step - loss: 0.0586 - accuracy: 0.9766 - val_loss: 0.2658 - val_accuracy: 0.9051
# Epoch 44/100
# 77/77 [==============================] - 95s 1s/step - loss: 0.0531 - accuracy: 0.9807 - val_loss: 0.1890 - val_accuracy: 0.9280
# Epoch 45/100
# 77/77 [==============================] - 87s 1s/step - loss: 0.0562 - accuracy: 0.9824 - val_loss: 0.1946 - val_accuracy: 0.9247
# Epoch 46/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0583 - accuracy: 0.9766 - val_loss: 0.2218 - val_accuracy: 0.9198
# Epoch 47/100
# 77/77 [==============================] - 84s 1s/step - loss: 0.0531 - accuracy: 0.9844 - val_loss: 0.1839 - val_accuracy: 0.9182
# Epoch 48/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0528 - accuracy: 0.9803 - val_loss: 0.2623 - val_accuracy: 0.9280
# Epoch 49/100
# 77/77 [==============================] - 86s 1s/step - loss: 0.0504 - accuracy: 0.9803 - val_loss: 0.2024 - val_accuracy: 0.9313
# Epoch 50/100
# 77/77 [==============================] - 87s 1s/step - loss: 0.0531 - accuracy: 0.9791 - val_loss: 0.1550 - val_accuracy: 0.9427
# Epoch 51/100
# 77/77 [==============================] - 84s 1s/step - loss: 0.0468 - accuracy: 0.9844 - val_loss: 0.1627 - val_accuracy: 0.9427
# Epoch 52/100
# 77/77 [==============================] - 84s 1s/step - loss: 0.0331 - accuracy: 0.9869 - val_loss: 0.2284 - val_accuracy: 0.9247
# Epoch 53/100
# 77/77 [==============================] - 84s 1s/step - loss: 0.0433 - accuracy: 0.9853 - val_loss: 0.2195 - val_accuracy: 0.9296
# Epoch 54/100
# 77/77 [==============================] - 86s 1s/step - loss: 0.0332 - accuracy: 0.9881 - val_loss: 0.1728 - val_accuracy: 0.9493
# Epoch 55/100
# 77/77 [==============================] - 85s 1s/step - loss: 0.0393 - accuracy: 0.9857 - val_loss: 0.1388 - val_accuracy: 0.9591
# Epoch 56/100
# 77/77 [==============================] - 93s 1s/step - loss: 0.0347 - accuracy: 0.9898 - val_loss: 0.2733 - val_accuracy: 0.9018
# Epoch 57/100
# 77/77 [==============================] - 94s 1s/step - loss: 0.0311 - accuracy: 0.9898 - val_loss: 0.2347 - val_accuracy: 0.9149
# Epoch 58/100
# 77/77 [==============================] - 91s 1s/step - loss: 0.0271 - accuracy: 0.9898 - val_loss: 0.1669 - val_accuracy: 0.9394
# Epoch 59/100
# 77/77 [==============================] - 84s 1s/step - loss: 0.0532 - accuracy: 0.9795 - val_loss: 0.2431 - val_accuracy: 0.9247
# Epoch 60/100
# 77/77 [==============================] - 85s 1s/step - loss: 0.0679 - accuracy: 0.9771 - val_loss: 0.2989 - val_accuracy: 0.9034
# Epoch 61/100
# 77/77 [==============================] - 100s 1s/step - loss: 0.0454 - accuracy: 0.9816 - val_loss: 0.1693 - val_accuracy: 0.9444
# Epoch 62/100
# 77/77 [==============================] - 102s 1s/step - loss: 0.0493 - accuracy: 0.9816 - val_loss: 0.1738 - val_accuracy: 0.9313
# Epoch 63/100
# 77/77 [==============================] - 105s 1s/step - loss: 0.0294 - accuracy: 0.9889 - val_loss: 0.2158 - val_accuracy: 0.9329
# Epoch 64/100
# 77/77 [==============================] - 94s 1s/step - loss: 0.0267 - accuracy: 0.9910 - val_loss: 0.1206 - val_accuracy: 0.9574
# Epoch 65/100
# 77/77 [==============================] - 93s 1s/step - loss: 0.0331 - accuracy: 0.9861 - val_loss: 0.1792 - val_accuracy: 0.9394
# Epoch 66/100
# 77/77 [==============================] - 90s 1s/step - loss: 0.0291 - accuracy: 0.9885 - val_loss: 0.1655 - val_accuracy: 0.9542
# Epoch 67/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0272 - accuracy: 0.9893 - val_loss: 0.1633 - val_accuracy: 0.9444
# Epoch 68/100
# 77/77 [==============================] - 84s 1s/step - loss: 0.0336 - accuracy: 0.9877 - val_loss: 0.1620 - val_accuracy: 0.9624
# Epoch 69/100
# 77/77 [==============================] - 84s 1s/step - loss: 0.0413 - accuracy: 0.9865 - val_loss: 0.2192 - val_accuracy: 0.9476
# Epoch 70/100
# 77/77 [==============================] - 91s 1s/step - loss: 0.0644 - accuracy: 0.9762 - val_loss: 0.2277 - val_accuracy: 0.9296
# Epoch 71/100
# 77/77 [==============================] - 89s 1s/step - loss: 0.0500 - accuracy: 0.9820 - val_loss: 0.1525 - val_accuracy: 0.9460
# Epoch 72/100
# 77/77 [==============================] - 86s 1s/step - loss: 0.0308 - accuracy: 0.9898 - val_loss: 0.2448 - val_accuracy: 0.9133
# Epoch 73/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0249 - accuracy: 0.9918 - val_loss: 0.1852 - val_accuracy: 0.9264
# Epoch 74/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0199 - accuracy: 0.9943 - val_loss: 0.2343 - val_accuracy: 0.9214
# Epoch 75/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0253 - accuracy: 0.9930 - val_loss: 0.3216 - val_accuracy: 0.9313
# Epoch 76/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0176 - accuracy: 0.9951 - val_loss: 0.1320 - val_accuracy: 0.9476
# Epoch 77/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0303 - accuracy: 0.9885 - val_loss: 0.1407 - val_accuracy: 0.9591
# Epoch 78/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0312 - accuracy: 0.9918 - val_loss: 0.2005 - val_accuracy: 0.9329
# Epoch 79/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0164 - accuracy: 0.9930 - val_loss: 0.1999 - val_accuracy: 0.9427
# Epoch 80/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0149 - accuracy: 0.9967 - val_loss: 0.1218 - val_accuracy: 0.9591
# Epoch 81/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0095 - accuracy: 0.9975 - val_loss: 0.1366 - val_accuracy: 0.9574
# Epoch 82/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0192 - accuracy: 0.9943 - val_loss: 0.1591 - val_accuracy: 0.9460
# Epoch 83/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0279 - accuracy: 0.9889 - val_loss: 0.2419 - val_accuracy: 0.9444
# Epoch 84/100
# 77/77 [==============================] - 87s 1s/step - loss: 0.0447 - accuracy: 0.9857 - val_loss: 0.2274 - val_accuracy: 0.9149
# Epoch 85/100
# 77/77 [==============================] - 85s 1s/step - loss: 0.0321 - accuracy: 0.9889 - val_loss: 0.4666 - val_accuracy: 0.8773
# Epoch 86/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0261 - accuracy: 0.9885 - val_loss: 0.2308 - val_accuracy: 0.9264
# Epoch 87/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0218 - accuracy: 0.9922 - val_loss: 0.1807 - val_accuracy: 0.9444
# Epoch 88/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0424 - accuracy: 0.9840 - val_loss: 0.1678 - val_accuracy: 0.9460
# Epoch 89/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0321 - accuracy: 0.9877 - val_loss: 0.2089 - val_accuracy: 0.9345
# Epoch 90/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0237 - accuracy: 0.9914 - val_loss: 0.3080 - val_accuracy: 0.9247
# Epoch 91/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0181 - accuracy: 0.9943 - val_loss: 0.1145 - val_accuracy: 0.9607
# Epoch 92/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0215 - accuracy: 0.9918 - val_loss: 0.1638 - val_accuracy: 0.9476
# Epoch 93/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0215 - accuracy: 0.9922 - val_loss: 0.1344 - val_accuracy: 0.9574
# Epoch 94/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0112 - accuracy: 0.9967 - val_loss: 0.1640 - val_accuracy: 0.9444
# Epoch 95/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0272 - accuracy: 0.9914 - val_loss: 0.1848 - val_accuracy: 0.9427
# Epoch 96/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0327 - accuracy: 0.9902 - val_loss: 0.1651 - val_accuracy: 0.9427
# Epoch 97/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0551 - accuracy: 0.9812 - val_loss: 0.1302 - val_accuracy: 0.9558
# Epoch 98/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0379 - accuracy: 0.9848 - val_loss: 0.2013 - val_accuracy: 0.9394
# Epoch 99/100
# 77/77 [==============================] - 84s 1s/step - loss: 0.0290 - accuracy: 0.9889 - val_loss: 0.3101 - val_accuracy: 0.9116
# Epoch 100/100
# 77/77 [==============================] - 83s 1s/step - loss: 0.0251 - accuracy: 0.9906 - val_loss: 0.1854 - val_accuracy: 0.9444
# 24/24 [==============================] - 6s 250ms/step - loss: 0.1428 - accuracy: 0.9620
# Test Loss: 0.1428, Test Accuracy: 0.9620
#                   precision    recall  f1-score   support
#
#    Benign Masses       0.97      0.98      0.97       495
# Malignant Masses       0.95      0.94      0.95       269
#
#         accuracy                           0.96       764
#        macro avg       0.96      0.96      0.96       764
#     weighted avg       0.96      0.96      0.96       764

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Compute ROC curve and ROC area for each class
fpr = {}
tpr = {}
roc_auc = {}
n_classes = len(np.unique(y_labels))
y_score = model.predict([X_cnn_test, X_lbp_test])
y_test_categorical = to_categorical(label_encoder.transform(y_test))
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_categorical[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Access the training history to plot the training and validation loss and accuracy.
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

# Plot training versus validation loss
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()

# Plot training versus validation accuracy
plt.subplot(1, 2, 2)
plt.plot(training_accuracy, label='Training Accuracy')
plt.plot(validation_accuracy, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.show()
